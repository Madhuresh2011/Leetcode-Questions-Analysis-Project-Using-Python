# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Leetcode_Questions_Dataset.csv")
data
# Out:
#       Question_No                                         Question Acceptance  \
# 0               1                                          Two Sum     53.80%
# 1               2                                  Add Two Numbers     44.10%
# 2               3   Longest Substring Without Repeating Characters     35.40%
# 3               4                      Median of Two Sorted Arrays     41.50%
# 4               5                    Longest Palindromic Substring     34.40%
# ...           ...                                              ...        ...
# 2908         3246                     Premier League Table Ranking     84.10%
# 2909         3247              Number of Subsequences with Odd Sum     55.00%
# 2910         3248                                  Snake in Matrix     82.20%
# 2911         3249                   Count the Number of Good Nodes     55.70%
# 2912         3250              Find the Count of Monotonic Pairs I     45.90%
#
#       isPremium Difficulty                                      Question_Link  \
# 0         False       Easy  https://leetcode.com/problems/two-sum/description
# 1         False     Medium  https://leetcode.com/problems/add-two-numbers/...
# 2         False     Medium  https://leetcode.com/problems/longest-substrin...
# 3         False       Hard  https://leetcode.com/problems/median-of-two-so...
# 4         False     Medium  https://leetcode.com/problems/longest-palindro...
# ...         ...        ...                                                ...
# 2908       True       Easy  https://leetcode.com/problems/premier-league-t...
# 2909       True     Medium  https://leetcode.com/problems/number-of-subseq...
# 2910      False       Easy  https://leetcode.com/problems/snake-in-matrix/...
# 2911      False     Medium  https://leetcode.com/problems/count-the-number...
# 2912      False       Hard  https://leetcode.com/problems/find-the-count-o...
#
#                                                Solution
# 0       https://leetcode.com/problems/two-sum/solutions
# 1     https://leetcode.com/problems/add-two-numbers/...
# 2     https://leetcode.com/problems/longest-substrin...
# 3     https://leetcode.com/problems/median-of-two-so...
# 4     https://leetcode.com/problems/longest-palindro...
# ...                                                 ...
# 2908  https://leetcode.com/problems/premier-league-t...
# 2909  https://leetcode.com/problems/number-of-subseq...
# 2910  https://leetcode.com/problems/snake-in-matrix/...
# 2911  https://leetcode.com/problems/count-the-number...
# 2912  https://leetcode.com/problems/find-the-count-o...
#
# [2913 rows x 7 columns]

# %%
data.drop(columns = ['Question_No'], inplace = True)
data
# Out:
#                                              Question Acceptance  isPremium  \
# 0                                             Two Sum     53.80%      False
# 1                                     Add Two Numbers     44.10%      False
# 2      Longest Substring Without Repeating Characters     35.40%      False
# 3                         Median of Two Sorted Arrays     41.50%      False
# 4                       Longest Palindromic Substring     34.40%      False
# ...                                               ...        ...        ...
# 2908                     Premier League Table Ranking     84.10%       True
# 2909              Number of Subsequences with Odd Sum     55.00%       True
# 2910                                  Snake in Matrix     82.20%      False
# 2911                   Count the Number of Good Nodes     55.70%      False
# 2912              Find the Count of Monotonic Pairs I     45.90%      False
#
#      Difficulty                                      Question_Link  \
# 0          Easy  https://leetcode.com/problems/two-sum/description
# 1        Medium  https://leetcode.com/problems/add-two-numbers/...
# 2        Medium  https://leetcode.com/problems/longest-substrin...
# 3          Hard  https://leetcode.com/problems/median-of-two-so...
# 4        Medium  https://leetcode.com/problems/longest-palindro...
# ...         ...                                                ...
# 2908       Easy  https://leetcode.com/problems/premier-league-t...
# 2909     Medium  https://leetcode.com/problems/number-of-subseq...
# 2910       Easy  https://leetcode.com/problems/snake-in-matrix/...
# 2911     Medium  https://leetcode.com/problems/count-the-number...
# 2912       Hard  https://leetcode.com/problems/find-the-count-o...
#
#                                                Solution
# 0       https://leetcode.com/problems/two-sum/solutions
# 1     https://leetcode.com/problems/add-two-numbers/...
# 2     https://leetcode.com/problems/longest-substrin...
# 3     https://leetcode.com/problems/median-of-two-so...
# 4     https://leetcode.com/problems/longest-palindro...
# ...                                                 ...
# 2908  https://leetcode.com/problems/premier-league-t...
# 2909  https://leetcode.com/problems/number-of-subseq...
# 2910  https://leetcode.com/problems/snake-in-matrix/...
# 2911  https://leetcode.com/problems/count-the-number...
# 2912  https://leetcode.com/problems/find-the-count-o...
#
# [2913 rows x 6 columns]

# %%
data.head(10)
# Out:
#                                           Question Acceptance  isPremium  \
# 0                                          Two Sum     53.80%      False
# 1                                  Add Two Numbers     44.10%      False
# 2   Longest Substring Without Repeating Characters     35.40%      False
# 3                      Median of Two Sorted Arrays     41.50%      False
# 4                    Longest Palindromic Substring     34.40%      False
# 5                                Zigzag Conversion     49.30%      False
# 6                                  Reverse Integer     29.20%      False
# 7                         String to Integer (atoi)     17.90%      False
# 8                                Palindrome Number     57.50%      False
# 9                      Regular Expression Matching     28.40%      False
#
#   Difficulty                                      Question_Link  \
# 0       Easy  https://leetcode.com/problems/two-sum/description
# 1     Medium  https://leetcode.com/problems/add-two-numbers/...
# 2     Medium  https://leetcode.com/problems/longest-substrin...
# 3       Hard  https://leetcode.com/problems/median-of-two-so...
# 4     Medium  https://leetcode.com/problems/longest-palindro...
# 5     Medium  https://leetcode.com/problems/zigzag-conversio...
# 6     Medium  https://leetcode.com/problems/reverse-integer/...
# 7     Medium  https://leetcode.com/problems/string-to-intege...
# 8       Easy  https://leetcode.com/problems/palindrome-numbe...
# 9       Hard  https://leetcode.com/problems/regular-expressi...
#
#                                             Solution
# 0    https://leetcode.com/problems/two-sum/solutions
# 1  https://leetcode.com/problems/add-two-numbers/...
# 2  https://leetcode.com/problems/longest-substrin...
# 3  https://leetcode.com/problems/median-of-two-so...
# 4  https://leetcode.com/problems/longest-palindro...
# 5  https://leetcode.com/problems/zigzag-conversio...
# 6  https://leetcode.com/problems/reverse-integer/...
# 7  https://leetcode.com/problems/string-to-intege...
# 8  https://leetcode.com/problems/palindrome-numbe...
# 9  https://leetcode.com/problems/regular-expressi...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2913 entries, 0 to 2912
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Question       2913 non-null   object
#  1   Acceptance     2913 non-null   object
#  2   isPremium      2913 non-null   bool
#  3   Difficulty     2913 non-null   object
#  4   Question_Link  2913 non-null   object
#  5   Solution       2913 non-null   object
# dtypes: bool(1), object(5)
# memory usage: 116.8+ KB

# %%
# Removing the percentage symbol
data['Acceptance'] = data['Acceptance'].apply(lambda x: x[:-1])
data
# Out:
#                                              Question Acceptance  isPremium  \
# 0                                             Two Sum      53.80      False
# 1                                     Add Two Numbers      44.10      False
# 2      Longest Substring Without Repeating Characters      35.40      False
# 3                         Median of Two Sorted Arrays      41.50      False
# 4                       Longest Palindromic Substring      34.40      False
# ...                                               ...        ...        ...
# 2908                     Premier League Table Ranking      84.10       True
# 2909              Number of Subsequences with Odd Sum      55.00       True
# 2910                                  Snake in Matrix      82.20      False
# 2911                   Count the Number of Good Nodes      55.70      False
# 2912              Find the Count of Monotonic Pairs I      45.90      False
#
#      Difficulty                                      Question_Link  \
# 0          Easy  https://leetcode.com/problems/two-sum/description
# 1        Medium  https://leetcode.com/problems/add-two-numbers/...
# 2        Medium  https://leetcode.com/problems/longest-substrin...
# 3          Hard  https://leetcode.com/problems/median-of-two-so...
# 4        Medium  https://leetcode.com/problems/longest-palindro...
# ...         ...                                                ...
# 2908       Easy  https://leetcode.com/problems/premier-league-t...
# 2909     Medium  https://leetcode.com/problems/number-of-subseq...
# 2910       Easy  https://leetcode.com/problems/snake-in-matrix/...
# 2911     Medium  https://leetcode.com/problems/count-the-number...
# 2912       Hard  https://leetcode.com/problems/find-the-count-o...
#
#                                                Solution
# 0       https://leetcode.com/problems/two-sum/solutions
# 1     https://leetcode.com/problems/add-two-numbers/...
# 2     https://leetcode.com/problems/longest-substrin...
# 3     https://leetcode.com/problems/median-of-two-so...
# 4     https://leetcode.com/problems/longest-palindro...
# ...                                                 ...
# 2908  https://leetcode.com/problems/premier-league-t...
# 2909  https://leetcode.com/problems/number-of-subseq...
# 2910  https://leetcode.com/problems/snake-in-matrix/...
# 2911  https://leetcode.com/problems/count-the-number...
# 2912  https://leetcode.com/problems/find-the-count-o...
#
# [2913 rows x 6 columns]

# %%
# Converting to numeric dtype
data['Acceptance'] = pd.to_numeric(data['Acceptance'], errors = 'coerce')
print(data)
# Out:
#                                              Question  Acceptance  isPremium  \
# 0                                             Two Sum        53.8      False
# 1                                     Add Two Numbers        44.1      False
# 2      Longest Substring Without Repeating Characters        35.4      False
# 3                         Median of Two Sorted Arrays        41.5      False
# 4                       Longest Palindromic Substring        34.4      False
# ...                                               ...         ...        ...
# 2908                     Premier League Table Ranking        84.1       True
# 2909              Number of Subsequences with Odd Sum        55.0       True
# 2910                                  Snake in Matrix        82.2      False
# 2911                   Count the Number of Good Nodes        55.7      False
# 2912              Find the Count of Monotonic Pairs I        45.9      False
#
#      Difficulty                                      Question_Link  \
# 0          Easy  https://leetcode.com/problems/two-sum/description
# 1        Medium  https://leetcode.com/problems/add-two-numbers/...
# 2        Medium  https://leetcode.com/problems/longest-substrin...
# 3          Hard  https://leetcode.com/problems/median-of-two-so...
# 4        Medium  https://leetcode.com/problems/longest-palindro...
# ...         ...                                                ...
# 2908       Easy  https://leetcode.com/problems/premier-league-t...
# 2909     Medium  https://leetcode.com/problems/number-of-subseq...
# 2910       Easy  https://leetcode.com/problems/snake-in-matrix/...
# 2911     Medium  https://leetcode.com/problems/count-the-number...
# 2912       Hard  https://leetcode.com/problems/find-the-count-o...
#
#                                                Solution
# 0       https://leetcode.com/problems/two-sum/solutions
# 1     https://leetcode.com/problems/add-two-numbers/...
# 2     https://leetcode.com/problems/longest-substrin...
# 3     https://leetcode.com/problems/median-of-two-so...
# 4     https://leetcode.com/problems/longest-palindro...
# ...                                                 ...
# 2908  https://leetcode.com/problems/premier-league-t...
# 2909  https://leetcode.com/problems/number-of-subseq...
# 2910  https://leetcode.com/problems/snake-in-matrix/...
# 2911  https://leetcode.com/problems/count-the-number...
# 2912  https://leetcode.com/problems/find-the-count-o...
#
# [2913 rows x 6 columns]

# %%
data.drop(columns = ['Question_Link', 'Solution'], inplace = True)
data
# Out:
#                                              Question  Acceptance  isPremium  \
# 0                                             Two Sum        53.8      False
# 1                                     Add Two Numbers        44.1      False
# 2      Longest Substring Without Repeating Characters        35.4      False
# 3                         Median of Two Sorted Arrays        41.5      False
# 4                       Longest Palindromic Substring        34.4      False
# ...                                               ...         ...        ...
# 2908                     Premier League Table Ranking        84.1       True
# 2909              Number of Subsequences with Odd Sum        55.0       True
# 2910                                  Snake in Matrix        82.2      False
# 2911                   Count the Number of Good Nodes        55.7      False
# 2912              Find the Count of Monotonic Pairs I        45.9      False
#
#      Difficulty
# 0          Easy
# 1        Medium
# 2        Medium
# 3          Hard
# 4        Medium
# ...         ...
# 2908       Easy
# 2909     Medium
# 2910       Easy
# 2911     Medium
# 2912       Hard
#
# [2913 rows x 4 columns]

# %%
most_accepted_ques = data.sort_values(by = 'Acceptance', ascending = False).head(100)
most_accepted_ques
# Out:
#                                                Question  Acceptance  \
# 2850                    Bitwise OR of Adjacent Elements        95.5
# 2425                  Return Length of Arguments Passed        94.4
# 1153             Print Immutable Linked List in Reverse        94.1
# 2791                                  Score of a String        93.0
# 2586                       Display the First Three Rows        93.0
# ...                                                 ...         ...
# 2677                                Minimum Number Game        86.0
# 2597                                 Reshape Data: Melt        86.0
# 2367         Apply Transform Over Each Element in Array        85.9
# 1253   Find a Corresponding Node of a Binary Tree in...        85.9
# 1645                                Convert Date Format        85.8
#
#       isPremium Difficulty
# 2850       True       Easy
# 2425      False       Easy
# 1153       True     Medium
# 2791      False       Easy
# 2586      False       Easy
# ...         ...        ...
# 2677      False       Easy
# 2597      False       Easy
# 2367      False       Easy
# 1253      False       Easy
# 1645       True       Easy
#
# [100 rows x 4 columns]

# %%
data['isPremium'] = data['isPremium'].astype(str).replace({
    'True': 'Premium',
    'False': 'Free'
})
print(data)
# Out:
#                                              Question  Acceptance isPremium  \
# 0                                             Two Sum        53.8      Free
# 1                                     Add Two Numbers        44.1      Free
# 2      Longest Substring Without Repeating Characters        35.4      Free
# 3                         Median of Two Sorted Arrays        41.5      Free
# 4                       Longest Palindromic Substring        34.4      Free
# ...                                               ...         ...       ...
# 2908                     Premier League Table Ranking        84.1   Premium
# 2909              Number of Subsequences with Odd Sum        55.0   Premium
# 2910                                  Snake in Matrix        82.2      Free
# 2911                   Count the Number of Good Nodes        55.7      Free
# 2912              Find the Count of Monotonic Pairs I        45.9      Free
#
#      Difficulty
# 0          Easy
# 1        Medium
# 2        Medium
# 3          Hard
# 4        Medium
# ...         ...
# 2908       Easy
# 2909     Medium
# 2910       Easy
# 2911     Medium
# 2912       Hard
#
# [2913 rows x 4 columns]

# %%
plt.figure(figsize=(8, 6))
plt.pie(data['Difficulty'].value_counts(), 
        labels=data['Difficulty'].unique(), 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=['#ff9999','#66b3ff','yellow'],
        explode = [0, 0, 0.1])

plt.title('Distribution of Question Difficulty', fontsize=16)
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.pie(data['isPremium'].value_counts(), 
        labels=data['isPremium'].unique(), 
        autopct='%1.1f%%', 
        startangle=90, 
        colors=['#f8c471','#249ee3'],
        explode = [0.1, 0])
plt.title('Distribution of Premium and Non-Premium Users', fontsize=16)
plt.axis('equal')

plt.show()

# %%
plt.figure(figsize = (15, 5))
sns.countplot(data = data, x = 'Difficulty', hue = 'isPremium')
plt.title("Premium Questions by Difficulty")

sns.despine()
plt.show()

# %%
most_accepted_qs = data.pivot_table(index = ['isPremium'], values = ['Acceptance'], aggfunc = 'mean').reset_index()
most_accepted_qs
# Out:
#   isPremium  Acceptance
# 0      Free   55.251312
# 1   Premium   60.612075

# %%
plt.figure(figsize = (10, 5))
sns.barplot(data = most_accepted_qs, x = 'isPremium', y = 'Acceptance')
plt.title("Most Accepted Question Type")

sns.despine()
plt.show()

# %%
most_accepted_by_diff = data.pivot_table(index = ['Difficulty'], values = ['Acceptance'], aggfunc = 'mean').reset_index()
most_accepted_by_diff
# Out:
#   Difficulty  Acceptance
# 0       Easy   67.037022
# 1       Hard   46.557209
# 2     Medium   55.377894

# %%
plt.figure(figsize = (10, 5))
sns.barplot(data = most_accepted_by_diff, x = 'Difficulty', y = 'Acceptance')
plt.title("Most Accepted Question Type")

sns.despine()
plt.show()
